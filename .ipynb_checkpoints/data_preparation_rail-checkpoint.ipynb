# %%
import pandas as pd
import matplotlib.pyplot as plt

rail = pd.read_csv("data/rail.csv", sep=";")[:-1]
rail = rail.replace(',','.', regex = True)

# %%
print(rail.head())
# Out:
#            Perioden  \
# 0  2009 1e kwartaal
# 1  2009 2e kwartaal
# 2  2009 3e kwartaal
# 3  2009 4e kwartaal
# 4  2010 1e kwartaal
#
#    Vervoerd ladinggewicht/Totaal vervoerd ladinggewicht (1 000 ton)  \
# 0                                               8967
# 1                                               7419
# 2                                               7797
# 3                                               9411
# 4                                               9308
#
#    Vervoerd ladinggewicht/Binnenlands goederenvervoer (1 000 ton)  \
# 0                                               1035
# 1                                               1258
# 2                                               1179
# 3                                               1086
# 4                                               1081
#
#    Vervoerd ladinggewicht/Internationaal goederenvervoer/Totaal internationaal goederenvervoer (1 000 ton)  \
# ...

# %%
rail = rail.rename(columns={"Ladingtonkilometer/Binnenlands goederenvervoer (mln tonkm)": "Binnenlands vervoer (mln tonkm)"})
rail = rail.rename(columns={"Ladingtonkilometer/Internationaal goederenvervoer/Aan- en afvoer/Totaal aan- en afvoer (mln tonkm)": "Aan- en afvoer interna (mln tonkm)"})
print(rail[["Perioden", "Binnenlands vervoer (mln tonkm)", "Aan- en afvoer (mln tonkm)"]])
# Out:
#              Perioden  Binnenlands vervoer (mln tonkm)  \
# 0    2009 1e kwartaal                              203
# 1    2009 2e kwartaal                              262
# 2    2009 3e kwartaal                              244
# 3    2009 4e kwartaal                              232
# 4    2010 1e kwartaal                              221
# ..                ...                              ...
# 65  2022 2e kwartaal*                              141
# 66  2022 3e kwartaal*                              142
# 67  2022 4e kwartaal*                              128
# 68              2022*                              551
# 69  2023 1e kwartaal*                              108
#
#     Aan- en afvoer (mln tonkm)
# 0                         1209
# 1                          875
# 2                          948
# 3                         1243
# 4                         1231
# ..                         ...
# 65                        1525
# 66                        1529
# ...
